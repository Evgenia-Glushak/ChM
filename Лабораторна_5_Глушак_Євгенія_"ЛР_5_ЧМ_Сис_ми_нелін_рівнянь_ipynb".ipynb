# %% [markdown]
# <a href="https://colab.research.google.com/github/Evgenia-Glushak/ChM/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0_5_%D0%93%D0%BB%D1%83%D1%88%D0%B0%D0%BA_%D0%84%D0%B2%D0%B3%D0%B5%D0%BD%D1%96%D1%8F_%22%D0%9B%D0%A0_5_%D0%A7%D0%9C_%D0%A1%D0%B8%D1%81_%D0%BC%D0%B8_%D0%BD%D0%B5%D0%BB%D1%96%D0%BD_%D1%80%D1%96%D0%B2%D0%BD%D1%8F%D0%BD%D1%8C_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Лабораторна робота 5
# Розв'язання систем нелінійних рівнянь.

# %% [markdown]
# 3 варіант Студентка Глушак Євгенія

# %%
import numpy as np
import matplotlib.pyplot as plt

# Область значень для x та y
x_min, x_max = -2, 2
y_min, y_max = -4, 3
step = 0.01

# Створюємо масиви значень x та y
x, y = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

# Рівняння системи
eq1 = np.sin(x) + 2 * y - 2
eq2 = np.cos(y - 1) + x - 0.7

# Створюємо графік
fig, ax = plt.subplots(figsize=(10, 10))

# Додаємо графік першого рівняння
ax.contour(x, y, eq1, levels=[0], colors='red')

# Додаємо графік другого рівняння
ax.contour(x, y, eq2, levels=[0], colors='blue')

# Налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')

# Додаємо стрілки на кінцях осей
ax.arrow(x_min, 0, x_max - x_min, 0, head_width=0.1, head_length=0.05, fc='black', ec='black')
ax.arrow(0, y_min, 0, y_max - y_min, head_width=0.1, head_length=0.2, fc='black', ec='black')

# Додаємо сітку
plt.grid(True)

# Показуємо графік
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Розв'язок системи рівнянь методом простої ітерації
import numpy as np
from scipy import optimize

# Початкове наближення
x0, y0 = 0.0, 0.0

# Задаємо функції з ітераційної форми системи
def f1(x):  # y = (2 - sin(x)) / 2
    return (2 - np.sin(x)) / 2

def f2(y):  # x = 0.7 - cos(y - 1)
    return 0.7 - np.cos(y - 1)

# Перевірка методу на збіжність
def iter(x, y, e):
    xn = x
    yn = y
    xn1 = f2(y)
    yn1 = f1(x)
    n = 1
    while (abs(xn1 - xn) >= e) or (abs(yn1 - yn) >= e):
        xn = xn1
        yn = yn1
        xn1 = f2(yn)
        yn1 = f1(xn)
        n += 1
    print('Simple iteration:')
    print('x =', xn, '\ny =', yn, '\nThe amount of iteration =', n)

# Виклик функції з точністю 0.0001
iter(x0, y0, 0.0001)

# Перевірка розв’язку через scipy.optimize
def f3(x):  # Система в початковій формі
    return np.sin(x[0]) + 2 * x[1] - 2, np.cos(x[1] - 1) + x[0] - 0.7

# Перевірка розв’язку
s = optimize.root(f3, [0., 0.], method='hybr')
print('Check:', s.x)
# Out:
# Simple iteration:
# x = -0.2898423863611558
# y = 1.1429078114583104
# The amount of iteration = 8
# Check: [-0.28980933  1.14288476]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Зверніть увагу!
# #Відповіді мають співпасти.
